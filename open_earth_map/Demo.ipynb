# %% [markdown]
# # OpenEarhMap Semantinc Segmentation
#
# original implementation found at https://github.com/bao18/open_earth_map/blob/main/Demo.ipynb
#
# ---

# %% [markdown]
# ### Requirements

# %%
# !pip install git+https://github.com/bao18/open_earth_map
# Out:
# Collecting git+https://github.com/bao18/open_earth_map
#   Cloning https://github.com/bao18/open_earth_map to /private/var/folders/2d/gysnzb3n1912sxr699qq0pfm0000gn/T/pip-req-build-sn_umqce
#   Running command git clone --filter=blob:none --quiet https://github.com/bao18/open_earth_map /private/var/folders/2d/gysnzb3n1912sxr699qq0pfm0000gn/T/pip-req-build-sn_umqce
#   Resolved https://github.com/bao18/open_earth_map to commit c525cbd65eb69cbb2e21b5681cf2e7ed25d57f6c
#   Preparing metadata (setup.py) ... done
# Collecting rasterio>=1.3.4
#   Using cached rasterio-1.3.4-cp39-cp39-macosx_10_15_x86_64.whl (30.9 MB)
# Collecting gdown>=4.6.0
#   Using cached gdown-4.6.0-py3-none-any.whl (14 kB)
# Collecting opencv-python>=4.7.0.68
#   Using cached opencv_python-4.7.0.68-cp37-abi3-macosx_10_13_x86_64.whl (51.7 MB)
# Collecting requests[socks]
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting filelock
#   Using cached filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 2.1 MB/s eta 0:00:00
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting numpy>=1.19.3
#   Downloading numpy-1.24.1-cp39-cp39-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 35.8 MB/s eta 0:00:0000:0100:01
# Collecting click-plugins
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting snuggs>=1.4.1
#   Using cached snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting click>=4.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting setuptools
#   Downloading setuptools-66.1.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.3 MB/s eta 0:00:0000:01
# Collecting cligj>=0.5
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting certifi
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting attrs
#   Using cached attrs-22.2.0-py3-none-any.whl (60 kB)
# Collecting pyparsing>=2.1.6
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.0.1-cp39-cp39-macosx_10_9_x86_64.whl (124 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Building wheels for collected packages: open-earth-map
#   Building wheel for open-earth-map (setup.py) ... done
#   Created wheel for open-earth-map: filename=open_earth_map-0.1-py3-none-any.whl size=8738 sha256=1a90e68c26e66ee0ccb0b2ccfadc32fb8c8d83814e604a084880f24183b36e29
#   Stored in directory: /private/var/folders/2d/gysnzb3n1912sxr699qq0pfm0000gn/T/pip-ephem-wheel-cache-vycnd78n/wheels/dc/c4/09/76f1e2398d5a6cfe1f00940973d6d32f52164b797df6bad487
# Successfully built open-earth-map
# Installing collected packages: charset-normalizer, urllib3, tqdm, soupsieve, six, setuptools, PySocks, pyparsing, numpy, idna, filelock, click, certifi, attrs, affine, snuggs, requests, opencv-python, cligj, click-plugins, beautifulsoup4, rasterio, gdown, open-earth-map
# Successfully installed PySocks-1.7.1 affine-2.4.0 attrs-22.2.0 beautifulsoup4-4.11.1 certifi-2022.12.7 charset-normalizer-3.0.1 click-8.1.3 click-plugins-1.1.1 cligj-0.7.2 filelock-3.9.0 gdown-4.6.0 idna-3.4 numpy-1.24.1 open-earth-map-0.1 opencv-python-4.7.0.68 pyparsing-3.0.9 rasterio-1.3.4 requests-2.28.2 setuptools-66.1.1 six-1.16.0 snuggs-1.4.7 soupsieve-2.3.2.post1 tqdm-4.64.1 urllib3-1.26.14

# %%
import os
import gdown
import zipfile

url = "https://drive.google.com/uc?export=download&confirm=pbef&id=1SqLqv1RCJdiUFnnfIce78M9nJF_KF11U"
output = "/work/remote_sensing/OpenEathMap_Mini.zip"
gdown.download(url, output, quiet=False)

with zipfile.ZipFile(output, 'r') as fzip:
    fzip.extractall()
os.remove(output)
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&confirm=pbef&id=1SqLqv1RCJdiUFnnfIce78M9nJF_KF11U
# To: /work/remote_sensing/OpenEathMap_Mini.zip
# 100%|██████████| 2.52G/2.52G [00:34<00:00, 72.9MB/s]

# %% [markdown]
# ### Imports
# ---

# %%
import time
import warnings
import numpy as np
import torch
import rasterio
import cv2
import open_earth_map as oem
import torchvision
from pathlib import Path
import matplotlib.pyplot as plt
import os
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Defines main parameters

# %%
# Path to the OpenEarthMap directory
OEM_DATA_DIR = "OpenEarthMap_Mini/"

# Training and validation file list
TRAIN_LIST = os.path.join(OEM_DATA_DIR, "train.txt")
VAL_LIST = os.path.join(OEM_DATA_DIR, "val.txt")

IMG_SIZE = 512
N_CLASSES = 9
LR = 0.0001
BATCH_SIZE = 4
NUM_EPOCHS = 10
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
OUTPUT_DIR = "outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# ### Prepares training and validation file lists.

# %%
fns = [f for f in Path(OEM_DATA_DIR).rglob("*.tif") if "/images/" in str(f)]
train_fns = [str(f) for f in fns if f.name in np.loadtxt(TRAIN_LIST, dtype=str)]
val_fns = [str(f) for f in fns if f.name in np.loadtxt(VAL_LIST, dtype=str)]

print("Total samples      :", len(fns))
print("Training samples   :", len(train_fns))
print("Validation samples :", len(val_fns))
# Out:
# Total samples      : 1068
# Training samples   : 663
# Validation samples : 92

# %% [markdown]
# ### Prepares training and validation augmentations.

# %%
train_augm = torchvision.transforms.Compose(
    [
        oem.transforms.Rotate(),
        oem.transforms.Crop(IMG_SIZE),
    ],
)

val_augm = torchvision.transforms.Compose(
    [
        oem.transforms.Resize(IMG_SIZE),
    ],
)

# %% [markdown]
# ### Defines training and validation dataloaders

# %%
train_data = oem.dataset.OpenEarthMapDataset(
    train_fns,
    n_classes=N_CLASSES,
    augm=train_augm,
)

val_data = oem.dataset.OpenEarthMapDataset(
    val_fns,
    n_classes=N_CLASSES,
    augm=val_augm,
)

# %%
import segmentation_models_pytorch as smp
model = oem.networks.UNet(in_channels=3, n_classes=N_CLASSES)
model = smp.Unet(
            encoder_name="mit_b2",
            encoder_weights="imagenet",
            in_channels=3,
            classes=N_CLASSES
        )
model = oem.utils.load_checkpoint(
        model,
        model_name="model.pth",
        model_dir="/work/remote_sensing/outputs/mit_b2_unet/Jaccard/newda_2/b8_lr0.0001_scosine_e600",
    )
DEVICE = "cuda"
model = model.eval().to(DEVICE)
# Out:
# Loaded model:model.pth (Epoch=363, Score=0.528)

# %%
fig, axs = plt.subplots(3, 5, figsize=(5*1.5, 3*1.5))
fig.subplots_adjust(top=1, bottom=0, left=0, right=1, hspace=0.01, wspace=0.01)

IDX = 1
for i in range(5):
    img, msk, fn = train_data[IDX]

    with torch.no_grad():
        prd = model(img.unsqueeze(0).to(DEVICE)).squeeze(0).cpu()
    prd = oem.utils.make_rgb(np.argmax(prd.numpy(), axis=0))
    
    img = np.moveaxis(img.numpy(), 0, -1)
    msk = oem.utils.make_rgb(np.argmax(msk.numpy(), axis=0))
    
    axs[0, i].imshow(img)
    axs[0, i].axis("off")
    axs[1, i].imshow(msk)
    axs[1, i].axis("off")
    axs[2, i].imshow(prd)
    axs[2, i].axis("off")

plt.savefig("/work/remote_sensing/outputs/result_1.png", dpi=1200)
plt.show()

# %%
train_data_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=BATCH_SIZE,
    num_workers=10,
    shuffle=True,
    drop_last=True,
)

val_data_loader = torch.utils.data.DataLoader(
    val_data,
    batch_size=BATCH_SIZE,
    num_workers=10,
    shuffle=False,
)

# %% [markdown]
# ### Defines the network architecture, optimizer, and criterion

# %%
network = oem.networks.UNet(in_channels=3, n_classes=N_CLASSES)
optimizer = torch.optim.Adam(network.parameters(), lr=LR)
# criterion = oem.losses.JaccardLoss()
criterion = oem.losses.FocalLoss()

# %% [markdown]
# ### Trains and validates the network

# %%
start = time.time()

max_score = 0
for epoch in range(NUM_EPOCHS):
    print(f"\nEpoch: {epoch + 1}")

    train_logs = oem.runners.train_epoch(
        model=network,
        optimizer=optimizer,
        criterion=criterion,
        dataloader=train_data_loader,
        device=DEVICE,
    )

    valid_logs = oem.runners.valid_epoch(
        model=network,
        criterion=criterion,
        dataloader=val_data_loader,
        device=DEVICE,
    )
    
    epoch_score = valid_logs["Score"]
    if max_score < epoch_score:
        max_score = epoch_score
        oem.utils.save_model(
            model=network,
            epoch=epoch,
            best_score=max_score,
            model_name="model.pth",
            output_dir=OUTPUT_DIR,
        )

print("Elapsed time: {:.3f} min".format((time.time() - start) / 60.0))
# Out:
# Epoch: 1
# Train:   1%|          | 2/165 [00:37<50:28, 18.58s/it, Loss=0.17, Score=0.0478]

# %% [markdown]
# # Testing

# %% [markdown]
# ### Prepares testing files

# %%
TEST_LIST = os.path.join(OEM_DATA_DIR, "test.txt")
PREDS_DIR = "predictions"
os.makedirs(PREDS_DIR, exist_ok=True)

img_paths = [f for f in Path(OEM_DATA_DIR).rglob("*.tif") if "/images/" in str(f)]
test_fns = [str(f) for f in img_paths if f.name in np.loadtxt(TEST_LIST, dtype=str)]

print("Total samples   :", len(img_paths))
print("Testing samples :", len(test_fns))
# Out:
# Total samples   : 1068
# Testing samples : 313

# %% [markdown]
# ### Defines test dataloader

# %%
test_data = oem.dataset.OpenEarthMapDataset(test_fns, n_classes=N_CLASSES, augm=None, testing=True)

# %% [markdown]
# ### Loads trained network

# %%
network = oem.networks.UNet(in_channels=3, n_classes=N_CLASSES)
network = oem.utils.load_checkpoint(network, model_name="model.pth", model_dir="outputs")
# Out:
# Loaded model:model.pth (Epoch=9, Score=0.086)

# %% [markdown]
# ### Makes predictions

# %%
import segmentation_models_pytorch as smp
model = oem.networks.UNet(in_channels=3, n_classes=N_CLASSES)
model = smp.Unet(
            encoder_name="mit_b2",
            encoder_weights="imagenet",
            in_channels=3,
            classes=N_CLASSES
        )
model = oem.utils.load_checkpoint(
        model,
        model_name="model.pth",
        model_dir="/work/remote_sensing/outputs/mit_b2_unet/Jaccard/newda_2/b8_lr0.0001_scosine_e600",
    )
DEVICE = "cuda"
model = model.eval().to(DEVICE)
# Out:
# Loaded model:model.pth (Epoch=363, Score=0.528)

# %%
NPLOT = 6
idxs = np.argsort(np.random.rand(len(test_fns)))[:NPLOT]

fig, axs = plt.subplots(2, NPLOT, figsize=(NPLOT*1.5, 2*1.5))
fig.subplots_adjust(top=1, bottom=0, left=0, right=1, hspace=0.01, wspace=0.01)

model.eval().to(DEVICE)
for i, idx in enumerate(idxs):
    img, fn = test_data[idx][0], test_data[idx][2]

    with torch.no_grad():
        prd = model(img.unsqueeze(0).to(DEVICE)).squeeze(0).cpu()
    prd = oem.utils.make_rgb(np.argmax(prd.numpy(), axis=0))

    fout = os.path.join(PREDS_DIR, fn.split("/")[-1])
    with rasterio.open(fn, "r") as src:
        profile = src.profile
        prd = cv2.resize(
            prd,
            (profile["width"], profile["height"]),
            interpolation=cv2.INTER_NEAREST,
        )
        with rasterio.open(fout, "w", **profile) as dst:
            for idx in src.indexes:
                dst.write(prd[:, :, idx - 1], idx)

    img = np.moveaxis(img.numpy(), 0, -1)
    axs[0, i].imshow(img)
    axs[0, i].set_title(fn.split("/")[-1][:-4])    
    axs[0, i].axis("off")
    axs[1, i].imshow(prd)
    axs[1, i].axis("off")

plt.savefig("/work/remote_sensing/outputs/result_testset_3.png", dpi=1200)
plt.show()
